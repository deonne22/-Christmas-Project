# %% [markdown]
# AMPOFO DEONNE GYAMFUA

# %% [markdown]
# 11230495

# %% [markdown]
# BIOMEDICAL ENGINEERING

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
mean_FA = dataset['fixed acidity'].mean()

# %%
mean_FA
# Out:
# 8.318335419274094

# %%
median_FA = dataset['fixed acidity'].median()

# %%
median_FA
# Out:
# 7.9

# %%
mode_FA = dataset['fixed acidity'].mode()

# %%
mode_FA
# Out:
# 0    7.2
# Name: fixed acidity, dtype: float64

# %%
dataset['volatile acidity']
# Out:
# 0       0.700
# 1       0.880
# 2       0.760
# 3       0.280
# 4       0.700
#         ...
# 1594    0.600
# 1595    0.550
# 1596    0.510
# 1597    0.645
# 1598    0.310
# Name: volatile acidity, Length: 1599, dtype: float64

# %%
mean_VA = dataset['volatile acidity'].mean()

# %%
mean_VA
# Out:
# 0.527747183979975

# %%
median_VA= dataset['volatile acidity'].median()

# %%
median_VA
# Out:
# 0.52

# %%
mode_VA = dataset['volatile acidity'].mode()

# %%
mode_VA
# Out:
# 0    0.6
# Name: volatile acidity, dtype: float64

# %%
dataset['citric acid']
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
#         ...
# 1594    0.08
# 1595    0.10
# 1596    0.13
# 1597    0.12
# 1598    0.47
# Name: citric acid, Length: 1599, dtype: float64

# %%
mean_CA = dataset['citric acid'].mean()

# %%
mean_CA
# Out:
# 0.2709756097560976

# %%
median_CA = dataset['citric acid'].median()

# %%
median_CA
# Out:
# 0.26

# %%
mode_CA = dataset['citric acid'].mode()

# %%
mode_CA
# Out:
# 0    0.0
# Name: citric acid, dtype: float64

# %%
dataset['residual sugar']
# Out:
# 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1594    2.0
# 1595    2.2
# 1596    2.3
# 1597    2.0
# 1598    3.6
# Name: residual sugar, Length: 1599, dtype: float64

# %%
mean_RS = dataset['residual sugar'].mean()

# %%
mean_RS
# Out:
# 2.53880550343965

# %%
median_RS = dataset['residual sugar'].median()

# %%
median_RS
# Out:
# 2.2

# %%
mode_RS = dataset['residual sugar'].mode()

# %%
mode_RS
# Out:
# 0    2.0
# Name: residual sugar, dtype: float64

# %%
dataset['chlorides']
# Out:
# 0       0.076
# 1       0.098
# 2       0.092
# 3       0.075
# 4       0.076
#         ...
# 1594    0.090
# 1595    0.062
# 1596    0.076
# 1597    0.075
# 1598    0.067
# Name: chlorides, Length: 1599, dtype: float64

# %%
mean_C = dataset['chlorides'].mean()

# %%
mean_C
# Out:
# 0.08747586206896552

# %%
median_C = dataset['chlorides'].median()

# %%
median_C
# Out:
# 0.079

# %%
mode_C = dataset['chlorides'].mode()

# %%
mode_C
# Out:
# 0    0.08
# Name: chlorides, dtype: float64

# %%
dataset['free sulfur dioxide']
# Out:
# 0       11.0
# 1       25.0
# 2       15.0
# 3       17.0
# 4       11.0
#         ...
# 1594    32.0
# 1595    39.0
# 1596    29.0
# 1597    32.0
# 1598    18.0
# Name: free sulfur dioxide, Length: 1599, dtype: float64

# %%
mean_FSD = dataset['free sulfur dioxide'].mean()

# %%
mean_FSD
# Out:
# 15.867334167709638

# %%
median_FSD = dataset['free sulfur dioxide'].median()

# %%
median_FSD
# Out:
# 14.0

# %%
mode_FSD = dataset['free sulfur dioxide'].mode()

# %%
mode_FSD
# Out:
# 0    6.0
# Name: free sulfur dioxide, dtype: float64

# %%
dataset['total sulfur dioxide']
# Out:
# 0       34.0
# 1       67.0
# 2       54.0
# 3       60.0
# 4       34.0
#         ...
# 1594    44.0
# 1595    51.0
# 1596    40.0
# 1597    44.0
# 1598    42.0
# Name: total sulfur dioxide, Length: 1599, dtype: float64

# %%
mean_TSD = dataset['total sulfur dioxide'].mean()

# %%
mean_TSD
# Out:
# 46.46779237023139

# %%
median_TSD = dataset['total sulfur dioxide'].median()

# %%
median_TSD
# Out:
# 38.0

# %%
mode_TSD = dataset['total sulfur dioxide'].mode()

# %%
mode_TSD
# Out:
# 0    28.0
# Name: total sulfur dioxide, dtype: float64

# %%
dataset['density']
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 4       0.99780
#          ...
# 1594    0.99490
# 1595    0.99512
# 1596    0.99574
# 1597    0.99547
# 1598    0.99549
# Name: density, Length: 1599, dtype: float64

# %%
mean_D = dataset['density'].mean()

# %%
mean_D
# Out:
# 0.996745519399249

# %%
median_D = dataset['density'].median()

# %%
median_D
# Out:
# 0.99675

# %%
mode_D = dataset['density'].mode()

# %%
mode_D
# Out:
# 0    0.9972
# Name: density, dtype: float64

# %%
dataset['pH']
# Out:
# 0       3.51
# 1       3.20
# 2       3.26
# 3       3.16
# 4       3.51
#         ...
# 1594    3.45
# 1595    3.52
# 1596    3.42
# 1597    3.57
# 1598    3.39
# Name: pH, Length: 1599, dtype: float64

# %%
mean_pH = dataset['pH'].mean()

# %%
mean_pH
# Out:
# 3.3111131957473416

# %%
median_pH = dataset['pH'].median()

# %%
median_pH
# Out:
# 3.31

# %%
mode_pH = dataset['pH'].mode()

# %%
mode_pH
# Out:
# 0    3.3
# Name: pH, dtype: float64

# %%
dataset['sulphates']
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
#         ...
# 1594    0.58
# 1595    0.76
# 1596    0.75
# 1597    0.71
# 1598    0.66
# Name: sulphates, Length: 1599, dtype: float64

# %%
mean_S = dataset['sulphates'].mean()

# %%
mean_S
# Out:
# 0.6581488430268917

# %%
median_S = dataset['sulphates'].median()

# %%
median_S
# Out:
# 0.62

# %%
mode_S = dataset['sulphates'].mode()

# %%
mode_S
# Out:
# 0    0.6
# Name: sulphates, dtype: float64

# %%
dataset['alcohol']
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %%
mean_A = dataset['alcohol'].mean()

# %%
mean_A
# Out:
# 10.422983114446529

# %%
median_A = dataset['alcohol'].median()

# %%
median_A
# Out:
# 10.2

# %%
mode_A = dataset['alcohol'].mode()

# %%
mode_A
# Out:
# 0    9.5
# Name: alcohol, dtype: float64

# %%
dataset['quality']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1594    5.0
# 1595    6.0
# 1596    6.0
# 1597    5.0
# 1598    6.0
# Name: quality, Length: 1599, dtype: float64

# %%
mean_Q = dataset['quality'].mean()

# %%
mean_Q
# Out:
# 5.635794743429287

# %%
median_Q = dataset['quality'].median()

# %%
median_Q
# Out:
# 6.0

# %%
mode_Q = dataset['quality'].mode()

# %%
mode_Q
# Out:
# 0    5.0
# Name: quality, dtype: float64

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(mean_FA)

# %%
dataset['volatile acidity'] = dataset['volatile acidity'].fillna(mean_VA)

# %%
dataset['citric acid'] = dataset['citric acid'].fillna(mean_CA)

# %%
dataset['residual sugar'] = dataset['residual sugar'].fillna(mean_RS)

# %%
dataset['chlorides'] = dataset['chlorides'].fillna(mean_C)

# %%
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(mean_FSD)

# %%
dataset['total sulfur dioxide'] = dataset['total sulfur dioxide'].fillna(mean_TSD)

# %%
dataset['density'] = dataset['density'].fillna(mean_D)

# %%
dataset['pH'] = dataset['pH'].fillna(mean_pH)

# %%
dataset['sulphates'] = dataset['sulphates'].fillna(mean_S)

# %%
dataset['alcohol'] = dataset['alcohol'].fillna(mean_A)

# %%
dataset['quality'] = dataset['quality'].fillna(mean_Q)

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(median_FA)

# %%
dataset['volatile acidity'] = dataset['volatile acidity'].fillna(median_VA)

# %%
dataset['citric acid'] = dataset['citric acid'].fillna(median_CA)

# %%
dataset['residual sugar'] = dataset['residual sugar'].fillna(median_RS)

# %%
dataset['chlorides'] = dataset['chlorides'].fillna(median_C)

# %%
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(median_FSD)

# %%
dataset['total sulfur dioxide'] = dataset['total sulfur dioxide'].fillna(median_TSD)

# %%
dataset['density'] = dataset['density'].fillna(median_D)

# %%
dataset['pH'] = dataset['pH'].fillna(median_pH)

# %%
dataset['sulphates'] = dataset['sulphates'].fillna(median_S)

# %%
dataset['alcohol'] = dataset['alcohol'].fillna(median_A)

# %%
dataset['quality'] = dataset['quality'].fillna(mean_Q)

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(mode_FA)

# %%
dataset['volatile acidity'] = dataset['volatile acidity'].fillna(mode_VA)

# %%
dataset['citric acid'] = dataset['citric acid'].fillna(mode_CA)

# %%
dataset['residual sugar'] = dataset['residual sugar'].fillna(median_RS)

# %%
dataset['chlorides'] = dataset['chlorides'].fillna(mode_C)

# %%
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(mode_FSD)

# %%
dataset['total sulfur dioxide'] = dataset['total sulfur dioxide'].fillna(mode_TSD)

# %%
dataset['density'] = dataset['density'].fillna(mode_D)

# %%
dataset['pH'] = dataset['pH'].fillna(mode_pH)

# %%
dataset['sulphates'] = dataset['sulphates'].fillna(mode_S)

# %%
dataset['alcohol'] = dataset['alcohol'].fillna(mode_A)

# %%
dataset['quality'] = dataset['quality'].fillna(mode_Q)

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740318          0.179036     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047058            10.455756             32.895324     0.001887
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
# histogram of fixed acidity content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['fixed acidity'],bins=20,color='yellow',edgecolor='black')
plt.title('Distribution Of Fixed Acidity Content in Red Wine')
plt.xlabel('Fixed Acidity Content')
plt.ylabel('Frequency')
plt.show()

# %%
# histogram of volatile acidity content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['volatile acidity'],bins=20,color='skyblue',edgecolor='black')
plt.title('Distribution Of Volatile Acidity Content in Red Wine')
plt.xlabel('Volatile Acidity Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of citric acid content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['citric acid'],bins=20,color='green',edgecolor='black')
plt.title('Distribution Of Citric Acid Content in Red Wine')
plt.xlabel('Citric Acid Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of residual sugar content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['residual sugar'],bins=20,color='brown',edgecolor='black')
plt.title('Distribution Of Residual Sugar Content in Red Wine')
plt.xlabel('Residual Sugar Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of chlorides content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['chlorides'],bins=20,color='purple',edgecolor='black')
plt.title('Distribution Of Chlorides Content in Red Wine')
plt.xlabel('Chlorides Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of free sulfur dioxide content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['free sulfur dioxide'],bins=20,color='pink',edgecolor='black')
plt.title('Distribution Of Free Sulfur Dioxide Content in Red Wine')
plt.xlabel('Free Sulfur Dioxide Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of total sulfur dioxide content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['total sulfur dioxide'],bins=20,color='red',edgecolor='black')
plt.title('Distribution Of Total Sulfur Dioxide Content in Red Wine')
plt.xlabel('Total Sulfur Dioxide Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of density

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['density'],bins=20,color='grey',edgecolor='black')
plt.title('Distribution Of Density Content in Red Wine')
plt.xlabel('Density Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of pH content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['pH'],bins=20,color='orange',edgecolor='black')
plt.title('Distribution Of pH Content in Red Wine')
plt.xlabel('pH Content')
plt.ylabel('Frequency')
plt.show()

# %%
# histogram of sulphates content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['sulphates'],bins=20,color='skyblue',edgecolor='black')
plt.title('Distribution Of Sulphates Content in Red Wine')
plt.xlabel('Sulphates Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of alcohol content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['alcohol'],bins=20,color='indigo',edgecolor='black')
plt.title('Distribution Of Alcohol Content in Red Wine')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.show()

# %%
#histogram of quality content

# %%
plt.figure(figsize=(8,6))
plt.hist(dataset['quality'],bins=20,color='gold',edgecolor='black')
plt.title('Distribution Of Quality Content in Red Wine')
plt.xlabel('Quality Content')
plt.ylabel('Frequency')
plt.show()

# %%
#scatter plot for fixed acidity vs. volatile acidity

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['fixed acidity'],dataset['volatile acidity'],color='cyan',alpha=0.5)
plt.title('Fixed Acidity Content vs. Volatile Acidity Content in Red Wine')
plt.xlabel('Fixed Acidity Content')
plt.ylabel('Volatile Acidity Content')
plt.show()

# %%
# scatter plot for citric acid vs. residual sugar

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['citric acid'],dataset['residual sugar'],color='yellow',alpha=0.5)
plt.title('Ciric Acid Content vs. Residual Sugar Content in Red Wine')
plt.xlabel('Citric Acid Content')
plt.ylabel('Residual Sugar Content')
plt.show()

# %%
#scatter plot for chlorides vs. free sulfur dioxide

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['chlorides'],dataset['free sulfur dioxide'],color='green',alpha=0.5)
plt.title('chlorides Content vs. Free Sulfur Dioxide Content in Red Wine')
plt.xlabel('chlorides Content')
plt.ylabel('Free Sulfur Dioxide Content')
plt.show()

# %%
#scatter plot for total sulfur dioxide vs. density

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['total sulfur dioxide'],dataset['density'],color='pink',alpha=0.5)
plt.title('Total Sulfur Dioxide Content vs. Density Content in Red Wine')
plt.xlabel('Total Sulfur Dioxide Content')
plt.ylabel('Density Content')
plt.show()

# %%
#scatter plot for pH vs. sulphate

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['pH'],dataset['sulphates'],color='orange',alpha=0.5)
plt.title('pH Content vs. Sulphates Content in Red Wine')
plt.xlabel('pH Content')
plt.ylabel('Sulphates Content')
plt.show()

# %%
#scatter plot for alcohol vs. quality

# %%
plt.figure(figsize=(8,6))
plt.scatter(dataset['alcohol'],dataset['quality'],color='red',alpha=0.5)
plt.title('Alcohol Content vs. Quality Content in Red Wine')
plt.xlabel('Alcohol Content')
plt.ylabel('Quality Content')
plt.show()

# %% [markdown]
# # insights and observation
# The histogram shows the distribution of fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol and quality contents peaking at a certain level.
#
# The scatter plot also shows the correlation between fixed acidity and volatile acidity,citric acid and residual sugar,chlorides and free sulfur dioxide,total sulfur dioxide and density,pH and sulphates,alcohol and quality contents.
